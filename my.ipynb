# %% [markdown]
# <a href="https://colab.research.google.com/github/RosaMitchell99/RosaMitchell99/blob/main/my.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install trimesh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.9/708.9 kB 19.1 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/openai/shap-e.git
# Out:
# ...
#   Cloning https://github.com/openai/shap-e.git to /tmp/pip-req-build-xb3whbzr
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/shap-e.git /tmp/pip-req-build-xb3whbzr
#   Resolved https://github.com/openai/shap-e.git to commit 50131012ee11c9d2617f3886c10f000d3c7a3b43
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-install-omhuak8b/clip_f15b6ebf12b14f0fa2af2fdbc412beea
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-omhuak8b/clip_f15b6ebf12b14f0fa2af2fdbc412beea
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python /content/drive/MyDrive/novelcity/code/3dgen/src/generate_assets.py
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ...
