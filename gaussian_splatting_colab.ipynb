# %% [markdown]
# <a href="https://colab.research.google.com/github/RosaMitchell99/RosaMitchell99/blob/main/gaussian_splatting_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /content/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 20.19 MiB/s, done.
# Resolving deltas: 100% (349/349), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# !pip install --upgrade setuptools wheel
# !apt-get install build-essential
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !pip install -v /content/gaussian-splatting/submodules/simple-knn
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# Processing ./gaussian-splatting/submodules/simple-knn
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info
#   writing /tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-dz97yfi1/simple_knn.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_ext
# ...

# %%
# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip tandt_db.zip

# !python train.py -s /content/gaussian-splatting/tandt/train

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/GaussianViewTest.zip
# !unzip GaussianViewTest.zip
# Out:
# --2025-02-25 03:06:48--  https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# Resolving huggingface.co (huggingface.co)... 3.165.160.59, 3.165.160.12, 3.165.160.61, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python /content/gaussian-splatting/render.py -m /content/GaussianViewTest/model
# Out:
# Looking for config file in /content/GaussianViewTest/model/cfg_args
# Config file found: /content/GaussianViewTest/model/cfg_args
# Rendering /content/GaussianViewTest/model
# dataset: {'sh_degree': 3, 'source_path': '/content/GaussianViewTest/train', 'model_path': '/content/GaussianViewTest/model', 'images': 'images', 'resolution': -1, 'white_background': False, 'data_device': 'cuda', 'eval': False} [25/02 03:22:46]
# Loading trained model at iteration 30000 [25/02 03:22:46]
# Reading camera 301/301 [25/02 03:22:47]
# Converting point3d.bin to .ply, will happen only the first time you open the scene. [25/02 03:22:47]
# Loading Training Cameras [25/02 03:22:48]
# Loading Test Cameras [25/02 03:22:56]
# Rendering progress: 100% 301/301 [02:19<00:00,  2.16it/s]
# Rendering progress: 0it [00:00, ?it/s]

# %%
# !ffmpeg -framerate 3 -i /content/GaussianViewTest/model/train/ours_30000/renders/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/renders.mp4
# !ffmpeg -framerate 3 -i /content/GaussianViewTest/model/train/ours_30000/gt/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/gt.mp4 -y
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !unzip testpics.zip
# Out:
# Archive:  testpics.zip
#    creating: testpics/
#   inflating: testpics/00000.png
#   inflating: testpics/00001.png
#   inflating: testpics/00002.png
#   inflating: testpics/00003.png
#   inflating: testpics/00004.png
#   inflating: testpics/00005.png
#   inflating: testpics/00006.png
#   inflating: testpics/00007.png
#   inflating: testpics/00008.png
#   inflating: testpics/00009.png

# %%
# !ffmpeg -framerate 3 -i /content/testpics/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/myrenders.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
